# %% [markdown]
# # *1. Gather a dataset regarding your identified problem for the ASEAN Data Science Explorer. Make sure that the dataset includes multiple variables.*

# %% [markdown]
# # *2. Load the dataset into pandas dataframe.*

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Food Waste data and research - by country.csv')
df
# Out:
#                         Country  combined figures (kg/capita/year)  \
# 0                   Afghanistan                                126
# 1                       Albania                                127
# 2                       Algeria                                135
# 3                       Andorra                                123
# 4                        Angola                                144
# ..                          ...                                ...
# 209  Venezuela (Boliv. Rep. of)                                116
# 210                    Viet Nam                                120
# 211                       Yemen                                148
# 212                      Zambia                                122
# 213                    Zimbabwe                                144
#
#      Household estimate (kg/capita/year)  Household estimate (tonnes/year)  \
# 0                                     82                           3109153
# ...

# %% [markdown]
# # *3. Prepare the data by applying appropriate data preprocessing techniques.*

# %%
data = df.copy()

# %%
data['Confidence in estimate'].unique()
# Out:
# array(['Very Low Confidence', 'Low Confidence', 'High Confidence',
#        'Medium Confidence'], dtype=object)

# %%
data.columns
# Out:
# Index(['Country', 'combined figures (kg/capita/year)',
#        'Household estimate (kg/capita/year)',
#        'Household estimate (tonnes/year)', 'Retail estimate (kg/capita/year)',
#        'Retail estimate (tonnes/year)',
#        'Food service estimate (kg/capita/year)',
#        'Food service estimate (tonnes/year)', 'Confidence in estimate',
#        'M49 code', 'Region', 'Source'],
#       dtype='object')

# %% [markdown]
# # *4. Analyze the data using descriptive analysis.*

# %%
data.columns
# Out:
# Index(['Country', 'combined figures (kg/capita/year)',
#        'Household estimate (kg/capita/year)',
#        'Household estimate (tonnes/year)', 'Retail estimate (kg/capita/year)',
#        'Retail estimate (tonnes/year)',
#        'Food service estimate (kg/capita/year)',
#        'Food service estimate (tonnes/year)', 'Confidence in estimate',
#        'M49 code', 'Region', 'Source'],
#       dtype='object')

# %%
data.sort_values(by = 'combined figures (kg/capita/year)', ascending = False, inplace = True) 
data.head()
# Out:
#       Country  combined figures (kg/capita/year)  \
# 116  Malaysia                                260
# 139   Nigeria                                233
# 159    Rwanda                                208
# 95     Israel                                178
# 77     Greece                                175
#
#      Household estimate (kg/capita/year)  Household estimate (tonnes/year)  \
# 116                                   91                           2921577
# 139                                  189                          37941470
# 159                                  164                           2075405
# 95                                   100                            848395
# 77                                   142                           1483996
#
#      Retail estimate (kg/capita/year)  Retail estimate (tonnes/year)  \
# 116                                79                        2518199
# 139                                16                        3143117
# ...

# %%
head = data.head(10).copy()
head.describe()
# Out:
#        combined figures (kg/capita/year)  Household estimate (kg/capita/year)  \
# count                          10.000000                            10.000000
# mean                          187.100000                           129.100000
# std                            35.164534                            29.897789
# min                           151.000000                            91.000000
# 25%                           165.000000                           108.500000
# 50%                           173.000000                           124.500000
# 75%                           200.500000                           139.500000
# max                           260.000000                           189.000000
#
#        Household estimate (tonnes/year)  Retail estimate (kg/capita/year)  \
# count                      1.000000e+01                         10.000000
# mean                       6.077998e+06                         24.700000
# ...

# %%
tail = data.tail(10).copy()
tail.describe()
# Out:
#        combined figures (kg/capita/year)  Household estimate (kg/capita/year)  \
# count                          10.000000                            10.000000
# mean                           81.900000                            48.600000
# std                             9.468662                            11.964763
# min                            61.000000                            33.000000
# 25%                            77.000000                            39.250000
# 50%                            84.000000                            50.000000
# 75%                            87.750000                            58.250000
# max                            94.000000                            65.000000
#
#        Household estimate (tonnes/year)  Retail estimate (kg/capita/year)  \
# count                      1.000000e+01                         10.000000
# mean                       9.687910e+06                         11.100000
# ...

# %%
household    = data[['Country','Region','Household estimate (kg/capita/year)','Household estimate (tonnes/year)']]
retail       = data[['Country','Region','Retail estimate (kg/capita/year)','Retail estimate (tonnes/year)']]
food_service = data[['Country','Region','Food service estimate (kg/capita/year)','Food service estimate (tonnes/year)']]

# %%
household[household['Region'] == 'South-eastern Asia']
# Out:
#                     Country              Region  \
# 116                Malaysia  South-eastern Asia
# 105  Lao People's Dem. Rep.  South-eastern Asia
# 150             Philippines  South-eastern Asia
# 32                 Cambodia  South-eastern Asia
# 130                 Myanmar  South-eastern Asia
# 190             Timor-Leste  South-eastern Asia
# 189                Thailand  South-eastern Asia
# 90                Indonesia  South-eastern Asia
# 210                Viet Nam  South-eastern Asia
# 172               Singapore  South-eastern Asia
# 27        Brunei Darussalam  South-eastern Asia
#
#      Household estimate (kg/capita/year)  Household estimate (tonnes/year)
# 116                                   91                           2921577
# 105                                   86                            618994
# 150                                   86                           9334477
# 32                                    86                           1423397
# ...

# %%
retail[retail['Region'] == 'South-eastern Asia']
# Out:
#                     Country              Region  \
# 116                Malaysia  South-eastern Asia
# 105  Lao People's Dem. Rep.  South-eastern Asia
# 150             Philippines  South-eastern Asia
# 32                 Cambodia  South-eastern Asia
# 130                 Myanmar  South-eastern Asia
# 190             Timor-Leste  South-eastern Asia
# 189                Thailand  South-eastern Asia
# 90                Indonesia  South-eastern Asia
# 210                Viet Nam  South-eastern Asia
# 172               Singapore  South-eastern Asia
# 27        Brunei Darussalam  South-eastern Asia
#
#      Retail estimate (kg/capita/year)  Retail estimate (tonnes/year)
# 116                                79                        2518199
# 105                                16                         112133
# 150                                16                        1690968
# 32                                 16                         257853
# ...

# %%
food_service[food_service['Region'] == 'South-eastern Asia']
# Out:
#                     Country              Region  \
# 116                Malaysia  South-eastern Asia
# 105  Lao People's Dem. Rep.  South-eastern Asia
# 150             Philippines  South-eastern Asia
# 32                 Cambodia  South-eastern Asia
# 130                 Myanmar  South-eastern Asia
# 190             Timor-Leste  South-eastern Asia
# 189                Thailand  South-eastern Asia
# 90                Indonesia  South-eastern Asia
# 210                Viet Nam  South-eastern Asia
# 172               Singapore  South-eastern Asia
# 27        Brunei Darussalam  South-eastern Asia
#
#      Food service estimate (kg/capita/year)  \
# 116                                      90
# 105                                      28
# 150                                      28
# 32                                       28
# 130                                      28
# 190                                      28
# 189                                      28
# ...

# %%
ASEAN = data[data['Region'] == 'South-eastern Asia'].copy()
ASEAN
# Out:
#                     Country  combined figures (kg/capita/year)  \
# 116                Malaysia                                260
# 105  Lao People's Dem. Rep.                                130
# 150             Philippines                                130
# 32                 Cambodia                                130
# 130                 Myanmar                                130
# 190             Timor-Leste                                130
# 189                Thailand                                123
# 90                Indonesia                                121
# 210                Viet Nam                                120
# 172               Singapore                                119
# 27        Brunei Darussalam                                119
#
#      Household estimate (kg/capita/year)  Household estimate (tonnes/year)  \
# 116                                   91                           2921577
# ...

# %%
#Plot the top 10 countries with maximum combined estimate
ASEAN.nlargest(100, ['combined figures (kg/capita/year)']).plot(x="Country", y="combined figures (kg/capita/year)",
        kind="barh",
        figsize=(10, 8), 
        ylabel='Countries',
        xlabel='combined figures (kg/capita/year)',
        title='combined figures (kg/capita/year)')
# Out:
# <Axes: title={'center': 'combined figures (kg/capita/year)'}, xlabel='combined figures (kg/capita/year)', ylabel='Countries'>

# %%
ASEAN.nlargest(100, ['Household estimate (kg/capita/year)']).plot(x="Country", y="Household estimate (kg/capita/year)",
        kind="barh",
        figsize=(10, 8), 
        ylabel='Countries',
        xlabel='Household estimate (kg/capita/year)',
        title='Household estimate (kg/capita/year)')
# Out:
# <Axes: title={'center': 'Household estimate (kg/capita/year)'}, xlabel='Household estimate (kg/capita/year)', ylabel='Countries'>

# %%
ASEAN.nlargest(100, ['Retail estimate (kg/capita/year)']).plot(x="Country", y="Retail estimate (kg/capita/year)",
        kind="barh",
        figsize=(10, 8), 
        ylabel='Countries',
        xlabel='Retail estimate (kg/capita/year)',
        title='Retail estimate (kg/capita/year)')
# Out:
# <Axes: title={'center': 'Retail estimate (kg/capita/year)'}, xlabel='Retail estimate (kg/capita/year)', ylabel='Countries'>

# %%
ASEAN.nlargest(100, ['Food service estimate (kg/capita/year)']).plot(x="Country", y="Food service estimate (kg/capita/year)",
        kind="barh",
        figsize=(10, 8), 
        ylabel='Countries',
        xlabel='Food service estimate (kg/capita/year)',
        title='Food service estimate (kg/capita/year)')
# Out:
# <Axes: title={'center': 'Food service estimate (kg/capita/year)'}, xlabel='Food service estimate (kg/capita/year)', ylabel='Countries'>

# %% [markdown]
# Based on the provided descriptive statistics detailing the visualization of the estimated food waste per sectors such as households, retail,
# and food service it can be seen here that among all of the countries within the ASEAN group, Malaysia ranks at the top with more than 80
# kg/capita/year in all of the sectors while the rest are usually less than 40 kg/capita/year in all sectors except household.
#
# Looking at the pattern as well, it can be extracted here that most of the food waste that are being produced are actually being sourced mostly
# from household due to most of the waste being generated are mostly and greatly in that specific sector.
#
# Additionally, compared to Malaysia, most of the countries nearly has the same output in all sectors which suggests that while all countries
# have slightly significat results in terms of their land size, the same cannot be said for Malaysia.

# %% [markdown]
# # *4. Perform correlation analysis.*

# %%
ASEAN[[
    'combined figures (kg/capita/year)',
    'Household estimate (kg/capita/year)',
    'Retail estimate (kg/capita/year)',
    'Food service estimate (kg/capita/year)'
]].corr(min_periods=3)
# Out:
#                                         combined figures (kg/capita/year)  \
# combined figures (kg/capita/year)                                1.000000
# Household estimate (kg/capita/year)                              0.643527
# Retail estimate (kg/capita/year)                                 0.995558
# Food service estimate (kg/capita/year)                           0.995087
#
#                                         Household estimate (kg/capita/year)  \
# combined figures (kg/capita/year)                                  0.643527
# Household estimate (kg/capita/year)                                1.000000
# Retail estimate (kg/capita/year)                                   0.568976
# Food service estimate (kg/capita/year)                             0.564958
#
#                                         Retail estimate (kg/capita/year)  \
# combined figures (kg/capita/year)                               0.995558
# ...

# %% [markdown]
# # *5. Interpret the results based on the descriptive and correlation analysis.*

# %%
Comparing the results from the previous descriptive statistics and the prior correlational, it can be seen here that there are very high
correlation in terms of the Food service and Retail sectors which suggest that most of the byproduct waste being produced are being sourced
from the same sources (e.g. they are sharing and providing each other their necessities which means that they share the waste themselves)
this can be further supported with the visualized output since when looking at the graphs for the three sectors, the Retail estimate
and Food service estimate nearly has the same results when compared to the Household sectors which has staggeringly more waste produced in
terms of kg/capita/year.
