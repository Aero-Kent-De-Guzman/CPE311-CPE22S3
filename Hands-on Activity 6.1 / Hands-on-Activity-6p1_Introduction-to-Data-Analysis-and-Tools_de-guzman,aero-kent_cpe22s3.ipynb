# %% [markdown]
# # **Hands-on Activity 6.1 Introduction to Data Analysis and Tools**
#
# **CPE311 Computational Thinking with Python**
#
# Name: De Guzman, Aero Kent
#
# Section: CPE22S3
#
# Performed on: 04/05/2025
#
# Submitted on: 04/05/2025
#
# Submitted to: Engr. Roman M. Richard

# %% [markdown]
# # **Supplementary Activities**

# %% [markdown]
# ## **Exercise 1**

# %% [markdown]
# Run the given code below for exercises 1 and 2, perform the given tasks without using any Python modules.

# %%
import random
random.seed(0)
salaries = [round(random.random()*1000000, -3) for _ in range(100)]

# %% [markdown]
# Using the data generated above, calculate the following statistics without importing anything from the statistics module in the
# standard library (https://docs.python.org/3/library/statistics.html) and then confirm your results match up to those that are
# obtained when using the statistics module (where possible):
# * Mean
# * Median
# * Mode (hint: check out the Counter in the collections module of the standard library at
# https://docs.python.org/3/library/collections.html#collections.Counter)
# * Sample variance
# * Sample standard deviation

# %%
print(salaries)
# Out:
# [844000.0, 758000.0, 421000.0, 259000.0, 511000.0, 405000.0, 784000.0, 303000.0, 477000.0, 583000.0, 908000.0, 505000.0, 282000.0, 756000.0, 618000.0, 251000.0, 910000.0, 983000.0, 810000.0, 902000.0, 310000.0, 730000.0, 899000.0, 684000.0, 472000.0, 101000.0, 434000.0, 611000.0, 913000.0, 967000.0, 477000.0, 865000.0, 260000.0, 805000.0, 549000.0, 14000.0, 720000.0, 399000.0, 825000.0, 668000.0, 1000.0, 494000.0, 868000.0, 244000.0, 325000.0, 870000.0, 191000.0, 568000.0, 239000.0, 968000.0, 803000.0, 448000.0, 80000.0, 320000.0, 508000.0, 933000.0, 109000.0, 551000.0, 707000.0, 547000.0, 814000.0, 540000.0, 964000.0, 603000.0, 588000.0, 445000.0, 596000.0, 385000.0, 576000.0, 290000.0, 189000.0, 187000.0, 613000.0, 657000.0, 477000.0, 90000.0, 758000.0, 877000.0, 923000.0, 842000.0, 898000.0, 923000.0, 541000.0, 391000.0, 705000.0, 276000.0, 812000.0, 849000.0, 895000.0, 590000.0, 950000.0, 580000.0, 451000.0, 660000.0, 996000.0, 917000.0, 793000.0, 82000.0, 613000.0, 486000.0]

# %%
# Mean

def my_mean(data):
  return sum(data) / len(data)

print(my_mean(salaries))
# Out:
# 585690.0

# %%
# Median

def my_median(data):
  sorted_data = sorted(data)
  if len(data) % 2 == 0: # Calculating the median when the the total is EVEN.
    return ( sorted_data[ int(len(data) / 2) ] +
             sorted_data[ int(len(data) / 2) + 1 ] ) / 2

  else:                  # Calculating the median when the the total is ODD.
    return sorted_data[ int ( ( len(data) - 1 ) / 2 ) ]

print(my_median(salaries))
# Out:
# 593000.0

# %%
# Mode

def my_mode(data, appearance = None, count = None):
  if appearance is None and count is None: # Initializing variables for recursion
    appearance = {}
    count      = 0

  if count < len(data): # This will append the key if it exists by 1
    try: appearance[data[count]] += 1
    except KeyError:  # This will append the dictionary the value does not exist
      appearance[data[count]] = 1

    return my_mode(data, appearance, count + 1)

  return max(appearance, key = appearance.get)

print(my_mode(salaries))
# Out:
# 477000.0

# %%
# Sample Variance

def sample_var(data):
  sum = 0
  for i in data:
    sum += (i - mean(data)) * (i - mean(data))

  return sum / ( len(data) - 1)

print(sample_var(salaries))
# Out:
# 70664054444.44444

# %%
# Sample Standard Deviation

def SS_deviation(data):
  return sample_var(data) ** 0.5

print(SS_deviation(salaries))
# Out:
# 265827.11382484

# %% [markdown]
# ## **EXERCISE 2**

# %% [markdown]
# Using the same data, calculate the following statistics using the functions in the statistics module where appropriate:
# * Range
# * Coefficient of variation Interquartile range
# * Quartile coefficient of dispersion

# %%
# Range

def data_range(data):
  return max(data) - min(data)

print(data_range(salaries))
# Out:
# 995000.0

# %%
# Coefficient of variation Interquartile range
import statistics as stat

def CV_IQR(data):
  sorted_data = sorted(data)
  Q = stat.quantiles(data, n=4)
  return (Q[2] - Q[0]) / stat.median(data) # ( IQR / median ), I do not know if both of them are supposed to be separete or not
                                                 # but if combined, this will be the formula. It is an uncommon analytical formula
                                                 # based on what I have search so I am not sure of its accuracy... Still if it is
                                                 # separate then the formula will be the IQR = Q3 - Q1 and CV = std / mean

print(CV_IQR(salaries))
# Out:
# 0.716044142614601

# %%
# Quartile coefficient of dispersion

def QC_dispersion(data):
  sorted_data = sorted(data)
  Q = stat.quantiles(data, n=4)
  return (( Q[2] - Q[0] ) / ( Q[2] + Q[0] ))

print(QC_dispersion(salaries))
# Out:
# 0.34491923941934166

# %% [markdown]
# ## **EXERCISE 3**

# %% [markdown]
# Load the diabetes.csv file. Convert the diabetes.csv into dataframe
# Perform the following tasks in the diabetes dataframe:
# 1. Identify the column names
# 2. Identify the data types of the data
# 3. Display the total number of records
# 4. Display the first 20 records
# 5. Display the last 20 records
# 6. Change the Outcome column to Diagnosis
# 7. Create a new column Classification that display "Diabetes" if the value of outcome is 1 , otherwise "No Diabetes"
# 8. Create a new dataframe "withDiabetes" that gathers data with diabetes
# 9. Create a new dataframe "noDiabetes" thats gathers data with no diabetes
# 10. Create a new dataframe "Pedia" that gathers data with age 0 to 19
# 11. Create a new dataframe "Adult" that gathers data with age greater than 19
# 12. Use numpy to get the average age and glucose value.
# 13. Use numpy to get the median age and glucose value.
# 1. Use numpy to get the middle values of glucose and age.
# 1. Use numpy to get the standard deviation of the skinthickness.

# %%
import pandas as pd

df = pd.read_csv('datasets/diabetes.csv')
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
# 1. Identify the column names

df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
# 2. Identify the data types of the data

df.dtypes
# Out:
# Pregnancies                   int64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                       int64
# dtype: object

# %%
# 3. Display the total number of records

print(df.index)
# or
print(df.shape)
# or
len(df)
# Out:
# RangeIndex(start=0, stop=768, step=1)
# (768, 9)
# 768

# %%
# 4. Display the first 20 records
df.head(20)
# Out:
#     Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0             6      148             72             35        0  33.6
# 1             1       85             66             29        0  26.6
# 2             8      183             64              0        0  23.3
# 3             1       89             66             23       94  28.1
# 4             0      137             40             35      168  43.1
# 5             5      116             74              0        0  25.6
# 6             3       78             50             32       88  31.0
# 7            10      115              0              0        0  35.3
# 8             2      197             70             45      543  30.5
# 9             8      125             96              0        0   0.0
# 10            4      110             92              0        0  37.6
# 11           10      168             74              0        0  38.0
# ...

# %%
# 5. Display the last 20 records
df.tail(20)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 748            3      187             70             22      200  36.4
# 749            6      162             62              0        0  24.3
# 750            4      136             70              0        0  31.2
# 751            1      121             78             39       74  39.0
# 752            3      108             62             24        0  26.0
# 753            0      181             88             44      510  43.3
# 754            8      154             78             32        0  32.4
# 755            1      128             88             39      110  36.5
# 756            7      137             90             41        0  32.0
# 757            0      123             72              0        0  36.3
# 758            1      106             76              0        0  37.5
# 759            6      190             92              0        0  35.5
# ...

# %%
# 6. Change the Outcome column to Diagnosis
df = df.rename(columns = {'Outcome' : 'Diagnosis'})
df.head(1)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
#
#    DiabetesPedigreeFunction  Age  Diagnosis
# 0                     0.627   50          1

# %%
# 7. Create a new column Classification that display "Diabetes" if the value of outcome is 1 , otherwise "No Diabetes"
df['Diabetes'] = df['Diagnosis'].apply(lambda x: 'Diabetes' if x == 1 else 'No Diabetes')
df.head(5)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Diagnosis     Diabetes
# 0                     0.627   50          1     Diabetes
# 1                     0.351   31          0  No Diabetes
# 2                     0.672   32          1     Diabetes
# 3                     0.167   21          0  No Diabetes
# 4                     2.288   33          1     Diabetes

# %%
# 8. Create a new dataframe "withDiabetes" that gathers data with diabetes

withDiabetes = df[df['Diagnosis'] == 1]
withDiabetes
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 2              8      183             64              0        0  23.3
# 4              0      137             40             35      168  43.1
# 6              3       78             50             32       88  31.0
# 8              2      197             70             45      543  30.5
# ..           ...      ...            ...            ...      ...   ...
# 755            1      128             88             39      110  36.5
# 757            0      123             72              0        0  36.3
# 759            6      190             92              0        0  35.5
# 761            9      170             74             31        0  44.0
# 766            1      126             60              0        0  30.1
#
#      DiabetesPedigreeFunction  Age  Diagnosis  Diabetes
# 0                       0.627   50          1  Diabetes
# ...

# %%
# 9. Create a new dataframe "noDiabetes" thats gathers data with no diabetes

withDiabetes = df[df['Diagnosis'] == 0]
withDiabetes
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 1              1       85             66             29        0  26.6
# 3              1       89             66             23       94  28.1
# 5              5      116             74              0        0  25.6
# 7             10      115              0              0        0  35.3
# 10             4      110             92              0        0  37.6
# ..           ...      ...            ...            ...      ...   ...
# 762            9       89             62              0        0  22.5
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Diagnosis     Diabetes
# ...

# %%
# 10. Create a new dataframe "Pedia" that gathers data with age 0 to 19

Pedia = df[df['Age'] <= 19]
Pedia # Does not output anything since there is no one below or equal the age of 19...
# Out:
# Empty DataFrame
# Columns: [Pregnancies, Glucose, BloodPressure, SkinThickness, Insulin, BMI, DiabetesPedigreeFunction, Age, Diagnosis, Diabetes]
# Index: []

# %%
# 11. Create a new dataframe "Adult" that gathers data with age greater than 19
Adult = df[df['Age'] > 19]
Adult # comparing the total with the amount extracted here, all participants are greater than 19...
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Diagnosis     Diabetes
# ...

# %%
# 12. Use numpy to get the average age and glucose value.
import numpy as np

print(np.average(df['Age']))
print(np.average(df['Glucose']))
# Out:
# 33.240885416666664
# 120.89453125

# %%
# 13. Use numpy to get the median age and glucose value.
import numpy as np

print(np.median(df['Age']))
print(np.median(df['Glucose']))
# Out:
# 29.0
# 117.0

# %%
# 14. Use numpy to get the middle values of glucose and age.
import numpy as np

print(np.sort(df['Age'])[len(df)//2])     # Still the same as median.
print(np.sort(df['Glucose'])[len(df)//2])
# Out:
# 29
# 117

# %%
# 15. Use numpy to get the standard deviation of the skinthickness.
import numpy as np

np.std(df['SkinThickness'])
# Out:
# 15.941828626496978

# %% [markdown]
# ## **CONCLUSION**

# %% [markdown]
# To conclude the following hands-on activity, it was all about the statistical application and introduction using python.
#
# Going forwards with the first exercise, it was all about the manual utilization of python without the module import of statistics which could have made the following easier. Implement of the commonly used statistical formula such as the mean, median, and mode as well as the variance and deviation are taught requested under here in order to both have another refreshener as well as to have both an understanding how the logic and implementation of it works in programming.
#
# Going forward with the middle exercise, it was now the implementation of the statistics module under python which contains numerous statistical formulas and analystical tools which can efficiently compute and return the desired values this was given as the second exercise after the previous one in order for us to understand how each functions found under this module can and could have been both implemented and be utilized. From all of the requested questions, the Coefficient Variance Interquartile Range for me was difficult due to it being uncommon for me, I have not encountered it in all my experience so I am unsure of the value it will return since all I know is Coefficient Variance and Interquartile Range. Nevertheless, it was still a good experience to be added for future use especially in data analysis where there analyzation of data is commonly being used.
#
# Lastly for the final exercise, it was now another introduction to pandas but with a brief implementation of numpy now which can be found at the latter end. Most of the given are the first half can be extracted by manipulating the columns of the dataframe as well as understanding the variables used in a dataframe such as the .columns and .shape so understanding both of those can make it easier to accomplish. On the otherhand, the creation of a new column based on another columns datas proved to be difficult to me to handle since using the assign fucntion is seems to be harder but utilizing the .apply() function made it easier to work around since overcoming the creation of a lambda function, how to exactly implement it into the dataframe/column is another problem which .apply() solved. I do not remember exactly when it was said to me but I remember back then that the .apply() function takes in arguments in a form of a function as well which I have heard after failing to convert the date datatype from object onto something numerical.
#
# All in all, the activity was all about the usage of statistical analysis tools as well as a brief implementation of of numpy with pandas. The first half was all about the logic and usage of the commonly used analysis tools using python whereas the latter end is now the brief introduction again with frame manipulation again with pandas as well as the implmentation of numpy with it.
